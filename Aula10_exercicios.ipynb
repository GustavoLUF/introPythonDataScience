# %%
import pandas as pd

# %%
df = pd.read_csv("dados/campanha_banco.csv")
df.head()
# Out:
#    idade  emprego  casado  educacao  possui_casa  emprestimo  qtd_contatos  \
# 0   56.0        3       1         0            0           0             1
# 1   57.0        7       1         3            0           0             1
# 2   37.0        7       1         3            2           0             1
# 3   40.0        0       1         1            0           0             1
# 4   56.0        7       1         3            0           2             1
#
#    mes  dia_semana  tempo_conta  qtd_campanhas  anonimizado_1  anonimizado_2  \
# 0    6           1          261              1            999              0
# 1    6           1          149              1            999              0
# 2    6           1          226              1            999              0
# 3    6           1          151              1            999              0
# 4    6           1          307              1            999              0
#
#    anonimizado_3  anonimizado_4  anonimizado_5  anonimizado_6  anonimizado_7  \
# 0              1            1.1         93.994          -36.4          4.857
# 1              1            1.1         93.994          -36.4          4.857
# 2              1            1.1         93.994          -36.4          4.857
# 3              1            1.1         93.994          -36.4          4.857
# 4              1            1.1         93.994          -36.4          4.857
#
#    anonimizado_8  aceitou_proposta
# 0         5191.0                 0
# 1         5191.0                 0
# 2         5191.0                 0
# 3         5191.0                 0
# 4         5191.0                 0

# %%
df.isnull().sum()
# Out:
# idade               0
# emprego             0
# casado              0
# educacao            0
# possui_casa         0
# emprestimo          0
# qtd_contatos        0
# mes                 0
# dia_semana          0
# tempo_conta         0
# qtd_campanhas       0
# anonimizado_1       0
# anonimizado_2       0
# anonimizado_3       0
# anonimizado_4       0
# anonimizado_5       0
# anonimizado_6       0
# anonimizado_7       0
# anonimizado_8       0
# aceitou_proposta    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40646 entries, 0 to 40645
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   idade             40646 non-null  float64
#  1   emprego           40646 non-null  int64
#  2   casado            40646 non-null  int64
#  3   educacao          40646 non-null  int64
#  4   possui_casa       40646 non-null  int64
#  5   emprestimo        40646 non-null  int64
#  6   qtd_contatos      40646 non-null  int64
#  7   mes               40646 non-null  int64
#  8   dia_semana        40646 non-null  int64
#  9   tempo_conta       40646 non-null  int64
#  10  qtd_campanhas     40646 non-null  int64
#  11  anonimizado_1     40646 non-null  int64
#  12  anonimizado_2     40646 non-null  int64
#  13  anonimizado_3     40646 non-null  int64
#  14  anonimizado_4     40646 non-null  float64
#  15  anonimizado_5     40646 non-null  float64
#  16  anonimizado_6     40646 non-null  float64
#  17  anonimizado_7     40646 non-null  float64
#  18  anonimizado_8     40646 non-null  float64
#  19  aceitou_proposta  40646 non-null  int64
# dtypes: float64(6), int64(14)
# memory usage: 6.2 MB

# %%
df.describe().T
# Out:
#                     count         mean         std       min       25%  \
# idade             40646.0    40.010555   10.435653    17.000    32.000
# emprego           40646.0     3.722507    3.592721     0.000     0.000
# casado            40646.0     1.173547    0.609067     0.000     1.000
# educacao          40646.0     3.744674    2.135433     0.000     2.000
# possui_casa       40646.0     1.073341    0.985195     0.000     0.000
# emprestimo        40646.0     0.326158    0.722435     0.000     0.000
# qtd_contatos      40646.0     0.362766    0.480804     0.000     0.000
# mes               40646.0     4.238154    2.316758     0.000     3.000
# dia_semana        40646.0     2.026891    1.388294     0.000     1.000
# tempo_conta       40646.0   258.500295  259.849137     0.000   102.000
# qtd_campanhas     40646.0     2.565640    2.773885     1.000     1.000
# anonimizado_1     40646.0   961.988412  188.105096     0.000   999.000
# anonimizado_2     40646.0     0.175269    0.497784     0.000     0.000
# anonimizado_3     40646.0     0.929169    0.365207     0.000     1.000
# anonimizado_4     40646.0     0.066457    1.575575    -3.400    -1.800
# anonimizado_5     40646.0    93.573482    0.581514    92.201    93.075
# anonimizado_6     40646.0   -40.559160    4.632759   -50.800   -42.700
# anonimizado_7     40646.0     3.604151    1.739557     0.634     1.344
# anonimizado_8     40646.0  5166.487256   72.542787  4963.600  5099.100
# aceitou_proposta  40646.0     0.113812    0.317587     0.000     0.000
#
#                        50%       75%       max
# idade               38.000    47.000    98.000
# emprego              2.000     7.000    11.000
# casado               1.000     2.000     3.000
# educacao             3.000     6.000     7.000
# possui_casa          2.000     2.000     2.000
# emprestimo           0.000     0.000     2.000
# qtd_contatos         0.000     1.000     1.000
# mes                  4.000     6.000     9.000
# dia_semana           2.000     3.000     4.000
# tempo_conta        179.000   320.000  4918.000
# qtd_campanhas        2.000     3.000    56.000
# anonimizado_1      999.000   999.000   999.000
# anonimizado_2        0.000     0.000     7.000
# anonimizado_3        1.000     1.000     2.000
# anonimizado_4        1.100     1.400     1.400
# anonimizado_5       93.749    93.994    94.767
# anonimizado_6      -41.800   -36.400   -26.900
# anonimizado_7        4.857     4.961     5.045
# anonimizado_8     5191.000  5228.100  5228.100
# aceitou_proposta     0.000     0.000     1.000

# %%
X = df.drop("aceitou_proposta", axis = 1)
y = df[["aceitou_proposta"]]

# %%
y
# Out:
#        aceitou_proposta
# 0                     0
# 1                     0
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 40641                 1
# 40642                 0
# 40643                 0
# 40644                 1
# 40645                 0
#
# [40646 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#        idade  emprego  casado  educacao  possui_casa  emprestimo  \
# 31104   33.0        7       1         3            2           0
# 10493   24.0        0       2         6            2           0
# 12532   48.0        4       1         3            0           0
# 11515   29.0        1       1         7            0           2
# 25407   39.0        1       1         2            0           0
# ...      ...      ...     ...       ...          ...         ...
# 6265    42.0        9       1         5            0           2
# 11284   43.0        0       1         3            0           0
# 38158   81.0       11       0         7            2           0
# 860     40.0        4       1         6            2           0
# 15795   35.0        7       2         3            0           0
#
#        qtd_contatos  mes  dia_semana  tempo_conta  qtd_campanhas  \
# 31104             0    6           2          397              1
# 10493             1    4           3          128             21
# 12532             0    3           3          705              1
# 11515             1    4           0           55              5
# 25407             0    7           4           73              1
# ...             ...  ...         ...          ...            ...
# 6265              1    6           4           96              5
# 11284             1    4           0         1422             10
# 38158             0    7           1          263              1
# 860               1    6           4          295              2
# 15795             0    3           3          520              1
#
#        anonimizado_1  anonimizado_2  anonimizado_3  anonimizado_4  \
# 31104            999              2              0           -1.8
# 10493            999              0              1            1.4
# 12532            999              0              1            1.4
# 11515            999              0              1            1.4
# 25407            999              0              1           -0.1
# ...              ...            ...            ...            ...
# 6265             999              0              1            1.1
# 11284            999              0              1            1.4
# 38158            999              1              0           -3.4
# 860              999              0              1            1.1
# 15795            999              0              1            1.4
#
#        anonimizado_5  anonimizado_6  anonimizado_7  anonimizado_8
# 31104         92.893          -46.2          1.327         5099.1
# 10493         94.465          -41.8          4.961         5228.1
# 12532         93.918          -42.7          4.962         5228.1
# 11515         94.465          -41.8          4.959         5228.1
# 25407         93.200          -42.0          4.120         5195.8
# ...              ...            ...            ...            ...
# 6265          93.994          -36.4          4.857         5191.0
# 11284         94.465          -41.8          4.959         5228.1
# 38158         92.649          -30.1          0.715         5017.5
# 860           93.994          -36.4          4.856         5191.0
# 15795         93.918          -42.7          4.961         5228.1
#
# [28452 rows x 19 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

normalizador = MinMaxScaler()

# %%
X_train = normalizador.fit_transform(X_train)

X_test = normalizador.fit_transform(X_test)

# %%
X_train
# Out:
# array([[0.19753086, 0.63636364, 0.33333333, ..., 0.19246862, 0.15710723,
#         0.51228733],
#        [0.08641975, 0.        , 0.66666667, ..., 0.37656904, 0.9809567 ,
#         1.        ],
#        [0.38271605, 0.36363636, 0.33333333, ..., 0.33891213, 0.98118341,
#         1.        ],
#        ...,
#        [0.79012346, 1.        , 0.        , ..., 0.86610879, 0.01836318,
#         0.20378072],
#        [0.28395062, 0.36363636, 0.33333333, ..., 0.60251046, 0.95715257,
#         0.85973535],
#        [0.22222222, 0.63636364, 0.66666667, ..., 0.33891213, 0.9809567 ,
#         1.        ]])

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

def avaliar_model(y_test, y_pred):
    # Criando a matriz de confusão
    conf_matrix = confusion_matrix(y_test, y_pred)

    # Plotando a matriz de confusão com um heatmap
    plt.figure(figsize=(8,6))
    sns.heatmap(conf_matrix, annot=True, fmt='g', cmap="Blues")
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.title('Confusion Matrix')
    plt.show()

    # Exibindo o classification report
    print(classification_report(y_test, y_pred))

# %%
from sklearn.linear_model import LogisticRegression

lrmodel = LogisticRegression()

lrmodel_treinado = lrmodel.fit(X_train, y_train)

y_predict = lrmodel_treinado.predict(X_test)

avaliar_model(y_test, y_predict)
# Out:
# C:\Users\gstvluf\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#               precision    recall  f1-score   support
#
#            0       0.91      0.99      0.95     10803
#            1       0.70      0.27      0.39      1391
#
#     accuracy                           0.90     12194
#    macro avg       0.81      0.63      0.67     12194
# weighted avg       0.89      0.90      0.88     12194
